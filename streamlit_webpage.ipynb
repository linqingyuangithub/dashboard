# %%
import pandas as pd
import numpy as np
import streamlit as st
import random
from streamlit_d3_demo import d3_line
import altair as alt
import os
import matplotlib.pyplot as plt
#from datetime import datetime
from datetime import date

st.title('Have a good day')
st.title('I love cats :blue[cool] :sunglasses:')
# Out:
# 2023-10-12 13:57:15.841
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\lyuan\Anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()

# %%
# Out:
#         Unnamed: 0     STYLE COLOR_CODE  \
# 0                0     11409       2148
# 1                1     11409       2148
# 2                2     27200       2012
# 3                3     32258          6
# 4                4   33858MN       1063
# ...            ...       ...        ...
# 662343        8924  Z8031MOD        999
# 662344        8925  Z8047NAT        250
# 662345        8926    ZA2301        001
# 662346        8927    ZA2301       2420
# 662347        8928    ZA2301       2421
#
#                                                STYLE_NAME SFCCOLORNAME  \
# 0                            JEEP POWERGLYDE SIDE BY SIDE         GREY
# 1                            JEEP POWERGLYDE SIDE BY SIDE         GREY
# 2                            SIMMONS BY THE BED CO SLEPER   GREY TWEED
# 3                                    CANOPY-SET-BB87191PS         PINK
# 4                   MN UMBRELLA PICNIC TABLE - COMPONENTS     MN DOTTY
# ...                                                   ...          ...
# 662343                        WOVEN BASKET PASTEL POM-POM     ASSORTED
# 662344                              NATURALIST BEIGE POUF        BEIGE
# 662345  2nd seat kit - BELLINI London S2D STROLLER/rai...        BLACK
# 662346  2nd seat kit - BELLINI London S2D STROLLER/rai...         Blue
# 662347  2nd seat kit - BELLINI London S2D STROLLER/rai...        Taupe
#
#        SFSGROUP_NAME3  UDF_ZZXCSLSV_015 ACTIVE_OK LOCATION  SFUQOH_V  SFUOP_V  \
# 0                 NaN              2.70         Y      BDC         0        0
# 1                 NaN              2.70         Y      CA1       155      171
# 2                 NaN              0.00         N      CA1         0        0
# 3                 NaN              0.00         Y      CA1         0        0
# 4                 NaN              0.00         Y      CA1         0        0
# ...               ...               ...       ...      ...       ...      ...
# 662343      MODERNIST              0.49         Y      PE1         4        0
# 662344     NATURALIST              5.36         N      CA1         0        0
# 662345        GENERIC              4.97         Y      PE1         0        0
# 662346        GENERIC              0.00         Y      PE1         0        0
# 662347        GENERIC              0.00         Y      PE1         0        0
#
#         SFUPK_V  SFUAVAILQOH_V  SFUOTSINV_VLL  UDF_ZZXCSLSV_046  \
# 0             0              0              0              0.00
# 1           116             39           -132            105.24
# 2             0              0              0              0.00
# 3             0              0              0              0.00
# 4             0              0              0              0.00
# ...         ...            ...            ...               ...
# 662343        0              4              4              1.96
# 662344        0              0              0              0.00
# 662345        0              0              0              0.00
# 662346        0              0              0              0.00
# 662347        0              0              0              0.00
#
#         SFCWIPINTRANS_VLL  Date           SKU
# 0                       0   516    11409-2148
# 1                     890   516    11409-2148
# 2                       0   516    27200-2012
# 3                       0   516       32258-6
# 4                       0   516  33858MN-1063
# ...                   ...   ...           ...
# 662343                  0  1004  Z8031MOD-999
# 662344                  0  1004  Z8047NAT-250
# 662345                  0  1004    ZA2301-001
# 662346                  0  1004   ZA2301-2420
# 662347                  0  1004   ZA2301-2421
#
# [662348 rows x 18 columns]
